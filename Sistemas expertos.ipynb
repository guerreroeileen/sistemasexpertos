# %% [markdown]
# Eileen Guerrero, Santiago Narvaez

# %% [markdown]
# <h1>Taller</h2>

# %% [markdown]
# <h3>"SISTEMA PARA UTILIZACIÓN EFICIENTE DE LOS RECURSOS DE FERTILIZACIÓN EN CULTIVOS DE CAÑA DE AZÚCAR EN EL VALLE GEOGRÁFICO DEL RIO CAUCA"</h3>

# %%
from pyknow import *
import ph
import condElect

class Soil(Fact):
    pass

class SoilAnalysis(KnowledgeEngine):
    @Rule(Soil(ph=P(lambda ph: ph>=7.2)))
    def rule_0(self):
        self.declare(Soil(pH= ph.ALCALINO))
        print("==> ph: ALCALINO")

    @Rule(Soil(ph=P(lambda ph: ph<7.2) & P(lambda ph: ph > 6.8)))
    def rule_1(self):
        self.declare(Soil(pH= ph.LIGERAMENTE_ALCALINO))
        print("==> ph: LIGERAMENTE ALCALINO")

    @Rule(Soil(ph=P(lambda ph: ph <= 6.8) & P(lambda ph: ph >= 6.2)))
    def rule_2(self):
        self.declare(Soil(pH=ph.NEUTRO))
        print("==> ph: NEUTRO")

    @Rule(Soil(ph=P(lambda ph: ph<6.2) & P(lambda ph: ph > 5.6)))
    def rule_3(self):
        self.declare(Soil(pH= ph.LIGERAMENTE_ACIDO))
        print("==> ph: LIGERAMENTE ACIDO")

    @Rule(Soil(ph=P(lambda ph: ph<=5.6)))
    def rule_4(self):
        self.declare(Soil(pH= ph.ACIDO))
        print("==> ph: ACIDO")

    @Rule(Soil(conductividad=P(lambda conductividad: conductividad < 0.8)))
    def rule_5(self):
        self.declare(Soil(condElectrica = condElect.BAJA))
        
        print("==> conductividadElectrica: BAJA")

    @Rule(Soil(conductividad=P(lambda conductividad: conductividad >= 0.8)))
    def rule_6(self):
        self.declare(Soil(condElectrica=condElect.ALTA))
        
        print("==> conductividadElectrica: ALTA")

    @Rule(Soil(pH=ph.ALCALINO))
    def rule_7(self):
        print("==> ExtractoSoluble: True")

    @Rule(Soil(pH=ph.LIGERAMENTE_ALCALINO))
    def rule_8(self):
        print("==> ExtractoSoluble: True")

    @Rule(AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.ALTA), Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_9(self):
        print(" ")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")

    @Rule(
        AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.ALTA), Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_10(self):
        print(" ")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(
        AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_11(self):
        print(" ")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")

    @Rule(
        AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_12(self):
        print(" ")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")

    @Rule(
        AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.BAJA), Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_13(self):
        print(" ")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(
        AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.BAJA), Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_14(self):
        print(" ")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(
        AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.BAJA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_15(self):
        print(" ")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(
        AND(Soil(pH=ph.ALCALINO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_16(self):
        print(" ")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores ")

    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.ALTA),
            Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_17(self):
        print(" ")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")
        print("     |-(5) Alta saturación de calcio")
        print("     |-(6) Salinidad en el suelo")
        print("     |-(7) Baja disponibilidad de Fosforo (Precipitación)")

    @Rule(AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.ALTA),
            Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_18(self):
        print(" ")
        print("     |-(1) Revisar las mediciones realizadas.")

    @Rule(AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.ALTA),
              Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_19(self):
        print(" ")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")



    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_20(self):
        print(" ")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")

    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.BAJA),
            Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_21(self):
        print(" ")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.BAJA),
              Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_22(self):
        print(" ")
        print("     |-(1) Revisar las mediciones realizadas.")


    @Rule(AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.BAJA),
              Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_23(self):
        print(" ")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores ")

    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ALCALINO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_24(self):
        print(" ")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores ")
        
        
    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.ALTA), Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_25(self):
        print(" ")
        print("     |-(1) Baja mineralizacion de MO (Baja actvidad microbiologica) ")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Salinidad en el suelo")
        
    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.ALTA), Soil(arena=P(lambda arena: arena >= 40.0))))
    def rule_26(self):
        print(" ")
        print("     |-(1) Revisar las mediciones realizadas.")
    
    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_27(self):
        print(" ")
        print("     |-(1) Salinidad en el suelo")
        
    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_28(self):
        print(" ")      
        
    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.BAJA), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_29(self):
        print(" ")          
        print("     |-(1) Baja mineralizacion de MO (Baja actvidad microbiologica)")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Limitaciones de movimiento de agua")    

    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.BAJA), Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_30(self):
        print(" ")
        print("     |-(1) Revisar las mediciones realizadas.")
        
    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.BAJA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_31(self):
        print(" ")  
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")       
        
    @Rule(
        AND(Soil(pH=ph.NEUTRO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_32(self):
        print(" ")  
        
    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ACIDO), Soil(condElectrica=condElect.ALTA), Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_33(self):
        print(" ")        
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")            
        print("     |-(4) Acumulacion de iones alcalinoterreos")
        print("     |-(5) Alta saturación de calcio")
        print("     |-(6) Salinidad en el suelo")            
        print("     |-(7) Baja disponibilidad de Fosforo (Precipitación)")        

    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ACIDO), Soil(condElectrica=condElect.ALTA), Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_34(self):
        print(" ")          
        print("     |-(1) Revisar las mediciones realizadas.") 
        
    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ACIDO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_35(self):
        print(" ")          
        print("     |-(1) Contenido de Aluminio")         
        print("     |-(2) Sulfatos altos")         
        print("     |-(3) Impedancia")         
        
    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ACIDO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_36(self):
        print(" ")          
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")         
        print("     |-(2) Baja disponibilidad de Calcio")               
        
    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ACIDO), Soil(condElectrica=condElect.BAJA), Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_37(self):
        print(" ")          
        print("     |-(1) Limitaciones de movimiento de agua")         
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")        
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")         
        print("     |-(4) Acumulacion de iones alcalinoterreos")          
        print("     |-(5) Baja disponibilidad de elementos menores ")         
     
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.BAJA), Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_38(self):
        print(" ")          
        print("     |-(1) Revisar las mediciones realizadas.")       
        
    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ACIDO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_39(self):
        print(" ")          
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")         
        print("     |-(2) Suelo Hidromorfico")        
        print("     |-(3) Limitaciones fisicas temporales")         
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")          
        print("     |-(5) Baja disponibilidad de elementos menores ")       
        
    @Rule(
        AND(Soil(pH=ph.LIGERAMENTE_ACIDO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_40(self):
        print(" ")          
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")         
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores ")         
        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.ALTA), Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_41(self):
        print(" ")          
        print("     |-(1) Limitaciones de movimiento de agua")         
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Acumulacion de iones alcalinoterreos")         
        print("     |-(4) Salinidad en el suelo")        
        print("     |-(5) Baja disponibilidad de Fosforo (Precipitación)")         
        print("     |-(6) Baja disponibilidad de Calcio")          
        print("     |-(7) Contenido de Aluminio")          
        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.ALTA), Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_42(self):
        print(" ")          
        print("     |-(1) Revisar las mediciones realizadas.")       
        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_43(self):
        print(" ")          
        print("     |-(1) Contenido de Aluminio")         
        print("     |-(2) Sulfatos altos")         
        print("     |-(3) Impedancia")   
        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo <= 40.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_44(self):
        print(" ")          
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")         
        print("     |-(2) Baja disponibilidad de Calcio")         
        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.BAJA), Soil(arcilla=P(lambda arcilla: arcilla >= 40.0))))
    def rule_45(self):
        print(" ")          
        print("     |-(1) Limitaciones de movimiento de agua")         
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")         
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")         
        print("     |-(4) Acumulacion de iones alcalinoterreos")  
        print("     |-(5) Baja disponibilidad de elementos menores ")         

        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.BAJA), Soil(arena=P(lambda arena: arena >= 50.0))))
    def rule_46(self):
        print(" ")          
        print("     |-(1) Revisar las mediciones realizadas.")                 
        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.BAJA), Soil(limo=P(lambda limo: limo >= 45.0))))
    def rule_47(self):
        print(" ")          
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")         
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")         
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")    
        print("     |-(5) Baja disponibilidad de elementos menores ") 
        
    @Rule(
        AND(Soil(pH=ph.ACIDO), Soil(condElectrica=condElect.ALTA), Soil(limo=P(lambda limo: limo >= 45.0)),
            Soil(arena=P(lambda arena: arena <= 40.0)), Soil(arcilla=P(lambda arcilla: arcilla <= 40.0))))
    def rule_48(self):
        print(" ")          
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")         
        print("     |-(2) Baja disponibilidad de Calcio")         
        print("     |-(3) Baja disponibilidad de elementos menores ")

# %%
engine = SoilAnalysis()
engine.reset() # Prepare the engine for the execution.
engine.declare(Soil(ph=3.4, conductividad=1.5, arcilla=28.1, arena=36.5, limo=41.2 )) # some data to test
engine.run() # Run it!
# Out:
# ==> conductividadElectrica: ALTA
# ==> ph: ACIDO
